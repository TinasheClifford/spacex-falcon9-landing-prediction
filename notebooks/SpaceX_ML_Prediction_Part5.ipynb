# %% [markdown]
# # **Space X Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Machine Learning Prediction - Part 5
#
# This notebook completes the machine learning pipeline for predicting SpaceX Falcon 9 first-stage landing success.

# %% [markdown]
# ## Model Comparison Summary
#
# After hyperparameter tuning with GridSearchCV (cv=10):
#
# ### Test Accuracy Results:
# - **Logistic Regression**: 83.33%
# - **Support Vector Machine (SVM)**: 83.33%
# - **Decision Tree Classifier**: 77.78%
# - **K-Nearest Neighbors (KNN)**: 83.33%
#
# ### Best Hyperparameters Found:
#
# **Logistic Regression:**
# - C: 0.01
# - penalty: l2
# - solver: lbfgs
# - Validation Accuracy: 84.64%
#
# **Support Vector Machine:**
# - C: 1.0
# - gamma: 0.03162277660168379
# - kernel: sigmoid
# - Validation Accuracy: 84.82%
#
# **Decision Tree:**
# - criterion: entropy
# - max_depth: 16
# - max_features: sqrt
# - min_samples_leaf: 2
# - min_samples_split: 10
# - splitter: random
# - Validation Accuracy: 88.93%
#
# **K-Nearest Neighbors:**
# - n_neighbors: 10
# - algorithm: auto
# - p: 1
# - Validation Accuracy: 84.82%
#
# ### Conclusion:
# Three models (Logistic Regression, SVM, and KNN) achieved the highest test accuracy of 83.33%. The SVM achieved the highest validation accuracy (84.82%), making it a strong choice for this prediction task.
